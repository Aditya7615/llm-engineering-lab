# %%
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline

llm = HuggingFacePipeline.from_model_id(
    model_id='TinyLlama/TinyLlama-1.1B-Chat-v1.0',
    task='text-generation',
    pipeline_kwargs=dict(
        temperature=0.5,
        max_new_tokens=100
    )
)
model = ChatHuggingFace(llm=llm)

result = model.invoke("What is the capital of India")

print(result.content)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.2.0)/charset_normalizer (3.4.6) doesn't match a supported version!
#   warnings.warn(
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Cancellation requested; stopping current tasks.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/huggingface_hub/file_download.py:549, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     547     progress.update(progress_bytes)
# --> 549 download_files(
#     550     xet_download_info,
#     551     endpoint=connection_info.endpoint,
#     552     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     553     token_refresher=token_refresher,
#     554     progress_updater=[progress_updater],
#     555     request_headers=xet_headers,
#     556 )
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline
# ----> 3 llm = HuggingFacePipeline.from_model_id(
#       4     model_id='TinyLlama/TinyLlama-1.1B-Chat-v1.0',
#       5     task='text-generation',
#       6     pipeline_kwargs=dict(
#       7         temperature=0.5,
#       8         max_new_tokens=100
#       9     )
#      10 )
#      11 model = ChatHuggingFace(llm=llm)
#      13 result = model.invoke("What is the capital of India")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_huggingface/llms/huggingface_pipeline.py:151, in HuggingFacePipeline.from_model_id(cls, model_id, task, backend, device, device_map, model_kwargs, pipeline_kwargs, batch_size, **kwargs)
#     148         raise ValueError(msg)
#     150     _model_kwargs["device_map"] = device_map
# --> 151 tokenizer = AutoTokenizer.from_pretrained(model_id, **_model_kwargs)
#     153 if backend in {"openvino", "ipex"}:
#     154     if task not in VALID_TASKS:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:749, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     746     if tokenizer_class is None:
#     747         tokenizer_class = TokenizersBackend
# --> 749     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     750 elif getattr(config, "tokenizer_class", None):
#     751     _class = config.tokenizer_class
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1690, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    1688 else:
#    1689     try:
# -> 1690         resolved_vocab_files[file_id] = cached_file(
#    1691             pretrained_model_name_or_path,
#    1692             file_path,
#    1693             cache_dir=cache_dir,
#    1694             force_download=force_download,
#    1695             proxies=proxies,
#    1696             local_files_only=local_files_only,
#    1697             token=token,
#    1698             user_agent=user_agent,
#    1699             revision=revision,
#    1700             subfolder=subfolder,
#    1701             _raise_exceptions_for_missing_entries=False,
#    1702             _commit_hash=commit_hash,
#    1703         )
#    1704     except OSError:
#    1705         # Re-raise any error raised by cached_file in order to get a helpful error message
#    1706         raise
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/utils/hub.py:277, in cached_file(path_or_repo_id, filename, **kwargs)
#     222 def cached_file(
#     223     path_or_repo_id: str | os.PathLike,
#     224     filename: str,
#     225     **kwargs,
#     226 ) -> str | None:
#     227     """
#     228     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     229
#    (...)
#     275     ```
#     276     """
# --> 277     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     278     file = file[0] if file is not None else file
#     279     return file
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/transformers/utils/hub.py:420, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     417 try:
#     418     if len(full_filenames) == 1:
#     419         # This is slightly better for only 1 file
# --> 420         hf_hub_download(
#     421             path_or_repo_id,
#     422             filenames[0],
#     423             subfolder=None if len(subfolder) == 0 else subfolder,
#     424             repo_type=repo_type,
#     425             revision=revision,
#     426             cache_dir=cache_dir,
#     427             user_agent=user_agent,
#     428             force_download=force_download,
#     429             proxies=proxies,
#     430             token=token,
#     431             local_files_only=local_files_only,
#     432         )
#     433     else:
#     434         snapshot_download(
#     435             path_or_repo_id,
#     436             allow_patterns=full_filenames,
#    (...)
#     444             local_files_only=local_files_only,
#     445         )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:89, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 89 return fn(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/huggingface_hub/file_download.py:986, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#     965     return _hf_hub_download_to_local_dir(
#     966         # Destination
#     967         local_dir=local_dir,
#    (...)
#     983         dry_run=dry_run,
#     984     )
#     985 else:
# --> 986     return _hf_hub_download_to_cache_dir(
#     987         # Destination
#     988         cache_dir=cache_dir,
#     989         # File info
#     990         repo_id=repo_id,
#     991         filename=filename,
#     992         repo_type=repo_type,
#     993         revision=revision,
#     994         # HTTP info
#     995         endpoint=endpoint,
#     996         etag_timeout=etag_timeout,
#     997         headers=hf_headers,
#     998         token=token,
#     999         # Additional options
#    1000         local_files_only=local_files_only,
#    1001         force_download=force_download,
#    1002         tqdm_class=tqdm_class,
#    1003         dry_run=dry_run,
#    1004     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/huggingface_hub/file_download.py:1202, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, force_download, tqdm_class, dry_run)
#    1199 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1201 with WeakFileLock(lock_path):
# -> 1202     _download_to_tmp_and_move(
#    1203         incomplete_path=Path(blob_path + ".incomplete"),
#    1204         destination_path=Path(blob_path),
#    1205         url_to_download=url_to_download,
#    1206         headers=headers,
#    1207         expected_size=expected_size,
#    1208         filename=filename,
#    1209         force_download=force_download,
#    1210         etag=etag,
#    1211         xet_file_data=xet_file_data,
#    1212         tqdm_class=tqdm_class,
#    1213     )
#    1214     if not os.path.exists(pointer_path):
#    1215         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/huggingface_hub/file_download.py:1826, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, headers, expected_size, filename, force_download, etag, xet_file_data, tqdm_class)
#    1824 if xet_file_data is not None and is_xet_available():
#    1825     logger.debug("Xet Storage is enabled for this repo. Downloading file from Xet Storage..")
# -> 1826     xet_get(
#    1827         incomplete_path=incomplete_path,
#    1828         xet_file_data=xet_file_data,
#    1829         headers=headers,
#    1830         expected_size=expected_size,
#    1831         displayed_filename=filename,
#    1832         tqdm_class=tqdm_class,
#    1833     )
#    1834 else:
#    1835     if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/huggingface_hub/file_download.py:549, in xet_get(incomplete_path, xet_file_data, headers, expected_size, displayed_filename, tqdm_class, _tqdm_bar)
#     546 def progress_updater(progress_bytes: float):
#     547     progress.update(progress_bytes)
# --> 549 download_files(
#     550     xet_download_info,
#     551     endpoint=connection_info.endpoint,
#     552     token_info=(connection_info.access_token, connection_info.expiration_unix_epoch),
#     553     token_refresher=token_refresher,
#     554     progress_updater=[progress_updater],
#     555     request_headers=xet_headers,
#     556 )
#
# KeyboardInterrupt:
